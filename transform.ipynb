# %% [markdown]
# # Setup

# %%
# Dependencies

from sqlalchemy import create_engine, inspect
import pandas as pd
import warnings

# %%
# Setting to reveal up to 500 rows in notebook

pd.set_option('display.max_rows', 500)

# %%
# Silence pink warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %%
def basic_clean(a_df):
    '''Performs initial cleaning of dataframe'''
    
    a_df = a_df.drop_duplicates(keep="first")
    
    return a_df

# %%
def all_caps(a_df, a_list):
    '''Renders string df columns in supplied list in all caps, returns dataframe'''
    
    for col in a_list:
        a_df[col] = a_df[col].str.upper()
        
    return a_df

# %%
def vc(a_ser):
    '''Return value_counts().to_frame() for a series'''
    
    return a_ser.value_counts().to_frame()

# %%
def clean_isbns(a_ser):
    '''Renders isbn series data as str and strips unwanted chars, returns a series'''
    
    a_ser = a_ser.astype("str") 
    a_ser = a_ser.str.rstrip(".0")
    
    return a_ser

# %%
def clean_prices(a_ser):
    '''Strips unwanted chars from price data and renders as float, returns a series'''
    
    a_ser = a_ser.astype("str") 
    a_ser = a_ser.str.lstrip("$")
    a_ser = a_ser.str.replace(",", "", regex=False)
    a_ser = a_ser.str.replace("PRICE NOT YET AVAILABLE**", "0.01", regex=False)
    a_ser = a_ser.str.replace("PREPAID", "0.01", regex=False)
    a_ser = a_ser.apply(lambda x: float(x))

    return a_ser

# %% [markdown]
# # Import courses_#.csv files into dataframe, clean and transform data

# %% [markdown]
# ### *courses_df*

# %%
# Read CSV files from List

csvs_files = ["Resources\\courses_1.csv", "Resources\\courses_2.csv", "Resources\\courses_3.csv"]

course_csv_list = (pd.read_csv(file) for file in csvs_files)

df1 = pd.concat(course_csv_list, ignore_index=True)

# %%
df1
# Out:
#         Unnamed: 0                        university  store_id  catalog_id  \
# 0                0             Ball State University    9301.0         NaN
# 1                1             Ball State University    9301.0         NaN
# 2                2             Ball State University    9301.0         NaN
# 3                3             Ball State University    9301.0         NaN
# 4                4             Ball State University    9301.0         NaN
# ...            ...                               ...       ...         ...
# 537816      538044  Florida International University   21551.0     10001.0
# 537817      538045  Florida International University   21551.0     10001.0
# 537818      538046  Florida International University   21551.0     10001.0
# 537819      538047  Florida International University   21551.0     10001.0
# 537820      538048  Florida International University   21551.0     10001.0
#
#                                             campus campus_id         term  \
# 0         Ball State University Official Bookstore       334  SPRING 2022
# 1         Ball State University Official Bookstore       334  SPRING 2022
# 2         Ball State University Official Bookstore       334  SPRING 2022
# 3         Ball State University Official Bookstore       334  SPRING 2022
# 4         Ball State University Official Bookstore       334  SPRING 2022
# ...                                            ...       ...          ...
# 537816  FIU - Maidique Campus & All Online Courses  19956951    FALL 2022
# 537817  FIU - Maidique Campus & All Online Courses  19956951    FALL 2022
# 537818  FIU - Maidique Campus & All Online Courses  19956951    FALL 2022
# 537819  FIU - Maidique Campus & All Online Courses  19956951    FALL 2022
# 537820  FIU - Maidique Campus & All Online Courses  19956951    FALL 2022
#
#            term_id department department_id course  course_id section  \
# 0       334_1_22_W        ACC       334_1_9    200        200       1
# 1       334_1_22_W        ACC       334_1_9    201        201      01
# 2       334_1_22_W        ACC       334_1_9    201        201      02
# 3       334_1_22_W        ACC       334_1_9    201        201      03
# 4       334_1_22_W        ACC       334_1_9    201        201      04
# ...            ...        ...           ...    ...        ...     ...
# 537816   107903977        PHC     107904486   6328  107916807     RVC
# 537817   107903977        PHC     107904486  6104C  107916813     RXD
# 537818   107903977        PHC     107904486   6102  107916814     RXD
# 537819   107903977        PHC     107904486   6102  107916814     RVC
# 537820   107903977        PHC     107904486   6099  107916815     U01
#
#        section_id             scanDate
# 0               1  2022-02-05 09:46:58
# 1              01  2022-02-05 09:46:58
# 2              02  2022-02-05 09:46:58
# 3              03  2022-02-05 09:46:58
# 4              04  2022-02-05 09:46:58
# ...           ...                  ...
# 537816  107902500  2022-02-05 09:46:58
# 537817  107902492  2022-02-05 09:46:58
# 537818  107902491  2022-02-05 09:46:58
# 537819  107902490  2022-02-05 09:46:58
# 537820  107902375  2022-02-05 09:46:58
#
# [537821 rows x 15 columns]

# %%
# Checking shape and dtypes of data

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537821 entries, 0 to 537820
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     537821 non-null  int64
#  1   university     537821 non-null  object
#  2   store_id       380343 non-null  float64
#  3   catalog_id     55691 non-null   float64
#  4   campus         516255 non-null  object
#  5   campus_id      537821 non-null  object
#  6   term           537821 non-null  object
#  7   term_id        537821 non-null  object
#  8   department     537821 non-null  object
#  9   department_id  537821 non-null  object
#  10  course         537821 non-null  object
#  11  course_id      537821 non-null  object
#  12  section        537821 non-null  object
#  13  section_id     537821 non-null  object
#  14  scanDate       537821 non-null  object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 61.5+ MB

# %%
# Eliminate dupes and drop unneeded columns

df1 = df1.drop_duplicates()

df1 = df1.drop(columns=["Unnamed: 0", "store_id", "catalog_id", "campus", "campus_id", "term_id", "scanDate"])

# %%
# Reorder columns and capitalize data where appropriate

df1 = df1[["department_id", "course_id", "section_id", "university", "term", "department", "course", "section"]]

all_caps(df1, ["university", "term", "department", "course", "section"])
# Out:
#        department_id  course_id section_id                        university  \
# 0            334_1_9        200          1             BALL STATE UNIVERSITY
# 1            334_1_9        201         01             BALL STATE UNIVERSITY
# 2            334_1_9        201         02             BALL STATE UNIVERSITY
# 3            334_1_9        201         03             BALL STATE UNIVERSITY
# 4            334_1_9        201         04             BALL STATE UNIVERSITY
# ...              ...        ...        ...                               ...
# 537816     107904486  107916807  107902500  FLORIDA INTERNATIONAL UNIVERSITY
# 537817     107904486  107916813  107902492  FLORIDA INTERNATIONAL UNIVERSITY
# 537818     107904486  107916814  107902491  FLORIDA INTERNATIONAL UNIVERSITY
# 537819     107904486  107916814  107902490  FLORIDA INTERNATIONAL UNIVERSITY
# 537820     107904486  107916815  107902375  FLORIDA INTERNATIONAL UNIVERSITY
#
#                term department course section
# 0       SPRING 2022        ACC    200       1
# 1       SPRING 2022        ACC    201      01
# 2       SPRING 2022        ACC    201      02
# 3       SPRING 2022        ACC    201      03
# 4       SPRING 2022        ACC    201      04
# ...             ...        ...    ...     ...
# 537816    FALL 2022        PHC   6328     RVC
# 537817    FALL 2022        PHC  6104C     RXD
# 537818    FALL 2022        PHC   6102     RXD
# 537819    FALL 2022        PHC   6102     RVC
# 537820    FALL 2022        PHC   6099     U01
#
# [537821 rows x 8 columns]

# %%
# Examine value counts on term column to begin consolidation into categories 

vc(df1["term"])
# Out:
#                         term
# SPRING 2022           287183
# FALL 2021              67170
# FALL 2022              19304
# FALL 21                16880
# WINTER - 2022          12627
# SPRING '22             12417
# WINTER 2022            12220
# SUMMER 2022            11341
# SPRING - 2022          10979
# FALL SEMESTER 2021      9352
# PANTHER BOOK PACK       9194
# SPRING 2022 OPT OUT     8846
# SPRING SEMEST. 2022     8631
# SPRING 22               7170
# SPRING '22 PULLMAN      4739
# SPRING '22 ONCAMPUS     4711
# SPRING TERM 2022        4379
# SPRING 22 BKT BNDLE     4095
# SPRING 2022 RES.        4039
# ALL SUMMER TERMS        3793
# MEDICAL SCHOOL 2021     2575
# SPRING/SUMMER 2022      2356
# WINTER QUARTER 2022     1468
# FALL QUARTER 2021       1271
# UCF SPRING 2022         1114
# 22SPDAY 1/3-4/24        1073
# SPRING 22 TERM 3         839
# SPRING '22 GLOBAL        716
# SPRING 22 TERM 4         712
# WSU SPRING 2022          625
# FALL 21 SUPPLEMENT       443
# 21FALLS                  439
# SPRING 22 SUPPLEMENT     416
# 21SPRGS                  410
# WINTER INTERSESSION      381
# SUMMER 22 TERM 5         337
# VC SPRING 2022           317
# SPRING22                 286
# 22DY03 (01/03-02/27      248
# PROFESSIONAL 21/22       242
# LAW SPRING - 2022        223
# SEC SPRING TERM 22       220
# WINTER 2021              220
# FIRST SPRING 22          188
# WINTER 22                179
# 1ST SPRING MOD 2022      162
# WINTER '22               158
# SPRING '22 EVERETT       151
# SPRING 1 '22 ONLINE      129
# 2ND SPRING MOD 2022      124
# WINTER SESSION 21-2       96
# SPRING 2022 SEMESTE       90
# SPRING TERM 3             81
# SPRING TERM 4             71
# WINTER SESSION 22         70
# SPRING FULL TERM 22       60
# MAYMESTER 2022            36
# TROY PC SPRING T-3        35
# 22DY04 (2/28-4/24)        32
# TROY PC SPRING T-4        28
# SELF-PACED COURSES        22
# WINTER '22 SFCC           22
# 21FALL2                   16
# TROY PC SPRING 2022       14
# 21FALL1                   13
# HIGH SCHOOL               13
# SUMMER 22 SEMESTER        10
# LATE SUMMER                8
# 21SPRG1                    8
# FALL 22 TERM 1             2
# PARALEGAL SPRING 22        1
# FALL 22 SEMESTER           1

# %%
# Use boolean mask to consolidate Spring 2022 term data 

spring_mask = df1["term"].str.contains("SPRING")

df1.loc[spring_mask, "term"] = "SPRING"


fall_mask = df1["term"].str.contains("FALL")

df1.loc[fall_mask, "term"] = "FALL"


summer_mask = df1["term"].str.contains("SUMMER")

df1.loc[summer_mask, "term"] = "SUMMER"


winter_mask = df1["term"].str.contains("WINTER")

df1.loc[winter_mask, "term"] = "WINTER"



junk_mask = ~(df1["term"].isin(["SPRING", "FALL", "SUMMER", "WINTER"]))

df1.loc[junk_mask, "term"] = "JUNK"

df1 = df1.loc[~(df1["term"]=="JUNK"), :]


vc(df1["term"])
# Out:
#           term
# SPRING  366147
# FALL    114891
# WINTER   27441
# SUMMER   15489

# %%
df1 = df1.reset_index(drop=True)

# %%
courses_df = df1.copy()

# %%
courses_df
# Out:
#        department_id  course_id section_id                        university  \
# 0            334_1_9        200          1             BALL STATE UNIVERSITY
# 1            334_1_9        201         01             BALL STATE UNIVERSITY
# 2            334_1_9        201         02             BALL STATE UNIVERSITY
# 3            334_1_9        201         03             BALL STATE UNIVERSITY
# 4            334_1_9        201         04             BALL STATE UNIVERSITY
# ...              ...        ...        ...                               ...
# 523963     107904486  107916807  107902500  FLORIDA INTERNATIONAL UNIVERSITY
# 523964     107904486  107916813  107902492  FLORIDA INTERNATIONAL UNIVERSITY
# 523965     107904486  107916814  107902491  FLORIDA INTERNATIONAL UNIVERSITY
# 523966     107904486  107916814  107902490  FLORIDA INTERNATIONAL UNIVERSITY
# 523967     107904486  107916815  107902375  FLORIDA INTERNATIONAL UNIVERSITY
#
#           term department course section
# 0       SPRING        ACC    200       1
# 1       SPRING        ACC    201      01
# 2       SPRING        ACC    201      02
# 3       SPRING        ACC    201      03
# 4       SPRING        ACC    201      04
# ...        ...        ...    ...     ...
# 523963    FALL        PHC   6328     RVC
# 523964    FALL        PHC  6104C     RXD
# 523965    FALL        PHC   6102     RXD
# 523966    FALL        PHC   6102     RVC
# 523967    FALL        PHC   6099     U01
#
# [523968 rows x 8 columns]

# %% [markdown]
# # Import textbooks_#.csv files into dataframe, clean and transform data

# %% [markdown]
# ### *textbooks_df*

# %%
# Read CSV files from List

csvs_files = ["Resources\\textbooks_1.csv", "Resources\\textbooks_2.csv", "Resources\\textbooks_3.csv",\
              "Resources\\textbooks_4.csv", "Resources\\textbooks_5.csv"]

course_csv_list = (pd.read_csv(file) for file in csvs_files)

df2 = pd.concat(course_csv_list, ignore_index=True)

# %%
df2
# Out:
#         Unnamed: 0  store_id  catalog_id campus_id     term_id department_id  \
# 0                0    9301.0         NaN       334  334_1_22_W       334_1_9
# 1                1    9301.0         NaN       334  334_1_22_W       334_1_9
# 2                2    9301.0         NaN       334  334_1_22_W       334_1_9
# 3                3    9301.0         NaN       334  334_1_22_W       334_1_9
# 4                4    9301.0         NaN       334  334_1_22_W       334_1_9
# ...            ...       ...         ...       ...         ...           ...
# 990722      992670   88196.0     10001.0  75156912   106477925     106757452
# 990723      992671   88196.0     10001.0  75156912   106477925     106757452
# 990724      992672   88196.0     10001.0  75156912   106477925     106757452
# 990725      992673   88196.0     10001.0  75156912   106477925     106757452
# 990726      992674   88196.0     10001.0  75156912   106477925     106757452
#
#         course_id section_id  \
# 0             200          1
# 1             201         01
# 2             201         02
# 3             201         03
# 4             201         04
# ...           ...        ...
# 990722  106762860  106737761
# 990723  106762860  106737762
# 990724  106762860  106737763
# 990725  106762860  106737764
# 990726  106762860  106737765
#
#                                                     title  edition  \
# 0                 Cengage Unlimited - Access (1 Semester)       18
# 1       Financial Accounting: Information for Decision...  10TH 21
# 2       Financial Accounting: Information for Decision...  10TH 21
# 3       Financial Accounting: Information for Decision...  10TH 21
# 4       Financial Accounting: Information for Decision...  10TH 21
# ...                                                   ...      ...
# 990722                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990723                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990724                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990725                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990726                   BIOL 252 LAB PRINTED ACCESS CODE      W21
#
#          publisher         book_type  \
# 0        CENGAGE U  Digital Purchase
# 1       MCG CUSTOM         New Print
# 2       MCG CUSTOM         New Print
# 3       MCG CUSTOM         New Print
# 4       MCG CUSTOM         New Print
# ...            ...               ...
# 990722  VAN-GRINER           BUY NEW
# 990723  VAN-GRINER           BUY NEW
# 990724  VAN-GRINER           BUY NEW
# 990725  VAN-GRINER           BUY NEW
# 990726  VAN-GRINER           BUY NEW
#
#                                                  book_url          book_id  \
# 0       https://bsu.bncollege.com/c/Cengage-Unlimited-...   MBS_5186058_dg
# 1       https://bsu.bncollege.com/c/Financial-Accounti...  MBS_5780024_new
# 2       https://bsu.bncollege.com/c/Financial-Accounti...  MBS_5780024_new
# 3       https://bsu.bncollege.com/c/Financial-Accounti...  MBS_5780024_new
# 4       https://bsu.bncollege.com/c/Financial-Accounti...  MBS_5780024_new
# ...                                                   ...              ...
# 990722  https://unc.bncollege.com/shop/BNCB_TextbookDe...   550036485535.0
# 990723  https://unc.bncollege.com/shop/BNCB_TextbookDe...   550036485535.0
# 990724  https://unc.bncollege.com/shop/BNCB_TextbookDe...   550036485535.0
# 990725  https://unc.bncollege.com/shop/BNCB_TextbookDe...   550036485535.0
# 990726  https://unc.bncollege.com/shop/BNCB_TextbookDe...   550036485535.0
#
#        no_textbook_message recommend_type          ISBN    price  \
# 0                      NaN   eBook Option  9.780358e+12  $119.99
# 1                      NaN       REQUIRED  9.781264e+12  $107.90
# 2                      NaN       REQUIRED  9.781264e+12  $107.90
# 3                      NaN       REQUIRED  9.781264e+12  $107.90
# 4                      NaN       REQUIRED  9.781264e+12  $107.90
# ...                    ...            ...           ...      ...
# 990722                 NaN       REQUIRED  9.781646e+12   $45.60
# 990723                 NaN       REQUIRED  9.781646e+12   $45.60
# 990724                 NaN       REQUIRED  9.781646e+12   $45.60
# 990725                 NaN       REQUIRED  9.781646e+12   $45.60
# 990726                 NaN       REQUIRED  9.781646e+12   $45.60
#
#                    scanDate
# 0       2022-02-05 09:46:58
# 1       2022-02-05 09:46:58
# 2       2022-02-05 09:46:58
# 3       2022-02-05 09:46:58
# 4       2022-02-05 09:46:58
# ...                     ...
# 990722  2022-02-05 09:46:58
# 990723  2022-02-05 09:46:58
# 990724  2022-02-05 09:46:58
# 990725  2022-02-05 09:46:58
# 990726  2022-02-05 09:46:58
#
# [990727 rows x 19 columns]

# %%
# Checking shape and dtypes of data

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990727 entries, 0 to 990726
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           990727 non-null  int64
#  1   store_id             669440 non-null  float64
#  2   catalog_id           121358 non-null  float64
#  3   campus_id            990727 non-null  object
#  4   term_id              990727 non-null  object
#  5   department_id        990727 non-null  object
#  6   course_id            990727 non-null  object
#  7   section_id           990727 non-null  object
#  8   title                645255 non-null  object
#  9   edition              633950 non-null  object
#  10  publisher            644969 non-null  object
#  11  book_type            645255 non-null  object
#  12  book_url             645255 non-null  object
#  13  book_id              645255 non-null  object
#  14  no_textbook_message  345472 non-null  object
#  15  recommend_type       641580 non-null  object
#  16  ISBN                 644811 non-null  float64
#  17  price                645255 non-null  object
#  18  scanDate             990727 non-null  object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 143.6+ MB

# %%
# Eliminate dupes and drop unneeded columns

df2 = df2.drop_duplicates()

df2 = df2.drop(columns=\
    ["Unnamed: 0", "store_id", "catalog_id", "campus_id", "term_id", "book_id",\
     "no_textbook_message", "recommend_type", "scanDate"])

# %%
# Reorder columns and capitalize data where appropriate

all_caps(df2, ["title", "edition", "publisher", "book_type", "price"])
# Out:
#        department_id  course_id section_id  \
# 0            334_1_9        200          1
# 1            334_1_9        201         01
# 2            334_1_9        201         02
# 3            334_1_9        201         03
# 4            334_1_9        201         04
# ...              ...        ...        ...
# 990722     106757452  106762860  106737761
# 990723     106757452  106762860  106737762
# 990724     106757452  106762860  106737763
# 990725     106757452  106762860  106737764
# 990726     106757452  106762860  106737765
#
#                                                     title  edition  \
# 0                 CENGAGE UNLIMITED - ACCESS (1 SEMESTER)       18
# 1       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# 2       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# 3       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# 4       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# ...                                                   ...      ...
# 990722                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990723                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990724                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990725                   BIOL 252 LAB PRINTED ACCESS CODE      W21
# 990726                   BIOL 252 LAB PRINTED ACCESS CODE      W21
#
#          publisher         book_type  \
# 0        CENGAGE U  DIGITAL PURCHASE
# 1       MCG CUSTOM         NEW PRINT
# 2       MCG CUSTOM         NEW PRINT
# 3       MCG CUSTOM         NEW PRINT
# 4       MCG CUSTOM         NEW PRINT
# ...            ...               ...
# 990722  VAN-GRINER           BUY NEW
# 990723  VAN-GRINER           BUY NEW
# 990724  VAN-GRINER           BUY NEW
# 990725  VAN-GRINER           BUY NEW
# 990726  VAN-GRINER           BUY NEW
#
#                                                  book_url          ISBN  \
# 0       https://bsu.bncollege.com/c/Cengage-Unlimited-...  9.780358e+12
# 1       https://bsu.bncollege.com/c/Financial-Accounti...  9.781264e+12
# 2       https://bsu.bncollege.com/c/Financial-Accounti...  9.781264e+12
# 3       https://bsu.bncollege.com/c/Financial-Accounti...  9.781264e+12
# 4       https://bsu.bncollege.com/c/Financial-Accounti...  9.781264e+12
# ...                                                   ...           ...
# 990722  https://unc.bncollege.com/shop/BNCB_TextbookDe...  9.781646e+12
# 990723  https://unc.bncollege.com/shop/BNCB_TextbookDe...  9.781646e+12
# 990724  https://unc.bncollege.com/shop/BNCB_TextbookDe...  9.781646e+12
# 990725  https://unc.bncollege.com/shop/BNCB_TextbookDe...  9.781646e+12
# 990726  https://unc.bncollege.com/shop/BNCB_TextbookDe...  9.781646e+12
#
#           price
# 0       $119.99
# 1       $107.90
# 2       $107.90
# 3       $107.90
# 4       $107.90
# ...         ...
# 990722   $45.60
# 990723   $45.60
# 990724   $45.60
# 990725   $45.60
# 990726   $45.60
#
# [990727 rows x 10 columns]

# %%
# Drop any rows where title, ISBN, and price are ALL missing (i.e., not much use for analysis)

df2 = df2.dropna(axis=0, subset=["title", "ISBN", "price"], how="all")

# %%
# Fill in missing values with default values  

df2 = df2.fillna(value={"edition":"unknown", "publisher":"unknown", "ISBN": 0.0, "price":"0.01"})

# %%
# Rename ISBN column to isbn 

df2 = df2.rename(columns={"ISBN":"isbn"})

# %%
# Transform isbn data

df2["isbn"] = clean_isbns(df2["isbn"])

# %%
# Transform price data

df2["price"] = clean_prices(df2["price"])

# %%
# Take a random sample of our dataframe to see if transformations are effective

df2.sample(50)
# Out:
#        department_id  course_id section_id  \
# 130550     774_1_112        302       1001
# 808783    8085_1_505       3010  027(8466)
# 414148   450_450_235        302        101
# 511743    452_452_19        135        001
# 467431   447_447_110        200        001
# 324869     330_1_250        261        001
# 648539     740_1_645       5740      24848
# 910845     107331272  107331756  107324648
# 476270     204_1_305       3773         03
# 145354    8011_1_168        152          1
# 629223     740_1_443       2300      22300
# 177710    8011_1_370       101C         80
# 226899     244_1_150       2201      15165
# 416843       572_1_6        689        600
# 950640     107331278  107331938  107325931
# 228429   632_632_362        153      18652
# 117978     490_1_435       2030        002
# 324991     330_1_250        429        001
# 599319     240_1_578        734        J70
# 960900     107331179  107333835  107326541
# 21751      334_1_908        619        800
# 261933   632_632_148        210       8137
# 707364   366_366_806        750        DL3
# 898272     107330934  107333450  107320568
# 849586     276_1_978       1300        001
# 904205     106757459  106764384  106741804
# 52100      480_1_150        424         A1
# 230845     336_1_120       3313      20186
# 285807     631_1_168        105      25103
# 133224     656_1_152       2314      31394
# 798876     276_1_320       3101        002
# 918210     107331385  107334973  107323807
# 979799     105805815  105810351  105803571
# 369128     693_1_190       0852        071
# 258171    632_632_75        493      12396
# 511018     317_1_136        202  SECTION 2
# 165104     246_1_135        260        002
# 48450       480_1_38        224         A1
# 238299     8387_1_45        545         01
# 248647     244_1_580       0661      13666
# 634044    8206_1_531        103      29880
# 987981     105073641  105075384  105062149
# 909528     105161347  105170823  105151879
# 188925    8011_1_465        10B         02
# 813297     707_1_545      C1102        004
# 847790     276_1_950       4121        001
# 734740     620_1_415        151        006
# 769201     707_1_260      C1102        033
# 70025      490_1_157       6240        301
# 15630      334_1_727        330         03
#
#                                                     title  edition  \
# 130550  SIMPLE STATISTICS : APPLICATIONS IN CRIMINOLOG...       07
# 808783  WHEN THE LITTLE THINGS COUNT . . . AND THEY AL...       07
# 414148          INFORMATION TECHNOLOGY PROJECT MANAGEMENT   9TH 19
# 511743                               I SHALL NOT BE MOVED       91
# 467431                   MATLAB PROGRAMMING FOR ENGINEERS   6TH 20
# 324869                                NO-DRAMA DISCIPLINE       14
# 648539  STUDY MANUAL PROGRAM FOR EXAMINATION FM (LOOSE...  15TH 21
# 910845              CRIMINALISTICS:INTRO.TO FORENSIC SCI.  12TH 18
# 476270                                 VOICES IN THE DARK       17
# 145354                         DRINK CULTURA : CHICANISMO       92
# 629223  MODERN BUSINESS STATISTICS WITH MICROSOFT EXCE...   7TH 21
# 177710                         MARUGOTO: INTERMEDIATE, B1       16
# 226899                           EVERYTHING'S AN ARGUMENT   8TH 19
# 416843                                    AIN'T I A WOMAN  (2ND)15
# 950640                           TRANSNATIONAL MANAGEMENT   8TH 18
# 228429                      INVITATION TO ASIAN RELIGIONS       16
# 117978                     NUTRITION: FROM SCIENCE TO YOU   4TH 19
# 324991           SURVEY OF HISTORIC COSTUME - STUDY GUIDE   6TH 15
# 599319  FUNDAMENTALS OF CASE MANAGEMENT PRACTICE: SKIL...   5TH 16
# 960900                              FISCAL ADMINISTRATION  10TH 18
# 21751                        ETHICS FOR BEHAVIOR ANALYSTS   3RD 16
# 261933            BLACK PANTHER: WHO IS THE BLACK PANTHER       15
# 707364  PRESIDENT'S BOOK OF SECRETS: THE UNTOLD STORY ...       16
# 898272                              ANALECTS OF CONFUCIUS       97
# 849586                                              SWEAT       17
# 904205                          HELPFUL: GUIDE TO LIFE...       19
# 52100              PHILOSOPHICAL INVESTIGATIONS - REVISED  (4TH)09
# 230845                                NO-DRAMA DISCIPLINE       14
# 285807  MAYFLOWER: A STORY OF COURAGE, COMMUNITY, AND WAR       06
# 133224  ORGANIC CHEM LAB SURVIVAL MANUAL: A STUDENT'S ...  10TH 16
# 798876  PERSUASION: SOCIAL INFLUENCE AND COMPLIANCE GA...   6TH 18
# 918210                                EXPLORING ECONOMICS   8TH 20
# 979799             EXPLORING RESEARCH IN MUSIC EDUC.+....       08
# 369128  ON JUSTICE, POWER, AND HUMAN NATURE: SELECTION...       93
# 258171             MORALITY OF WAR (EXPANDED AND UPDATED)   2ND 13
# 511018  VIA DELLA GRAMMATICA FOR ENGLISH SPEAKERS: THE...       11
# 165104                                      BOOK OF PROOF   3RD 18
# 48450                                            ORESTEIA       98
# 238299  COMPUTATIONAL GEOMETRY : ALGORITHMS AND APPLIC...   3RD 08
# 248647            ELEMENTARY ALGEBRA (OER) - 2 VOLUME SET   2ND 20
# 634044                                  BLIND EYE-UPDATED  (REV)99
# 987981                                   WHY IS THAT ART?   3RD 17
# 909528             HEALTH PROGRAM PLANNING+EVAL.-W/ACCESS   5TH 22
# 188925  ALFRED'S BASIC ADULT ALL-IN-ONE COURSE - WITH DVD       11
# 813297                        MINNA NO NIHONGO II: BOOK 1  (2ND)14
# 847790  MINDTAP SPANISH, 4 TERM (24 MONTHS) PRINTED AC...   7TH 19
# 734740                               GLOBAL COMMUNICATION   5TH 20
# 769201                      UTILITARIANISM AND ON LIBERTY  (2ND)03
# 70025       UNIX AND LINUX SYSTEM ADMINISTRATION HANDBOOK   5TH 18
# 15630   PUBLICATION MANUAL OF THE AMERICAN PSYCHOLOGIC...   7TH 20
#
#          publisher          book_type  \
# 130550         OXF          NEW PRINT
# 808783  HACHETTE B  USED PRINT RENTAL
# 414148   CENGAGE L         USED PRINT
# 511743   PENG RAND  USED PRINT RENTAL
# 467431   CENGAGE L  USED PRINT RENTAL
# 324869   PENG RAND         USED PRINT
# 648539       ACTEX         USED PRINT
# 910845     PEARSON           RENT NEW
# 476270   PENG RAND  USED PRINT RENTAL
# 145354  INGRAM PUB          NEW PRINT
# 629223   CENGAGE L         USED PRINT
# 177710  KINOKUNIYA         USED PRINT
# 226899  MAC HIGHER   NEW PRINT RENTAL
# 416843      TAYLOR   NEW PRINT RENTAL
# 950640        CAMB            BUY NEW
# 228429         OXF          NEW PRINT
# 117978     PEARSON  USED PRINT RENTAL
# 324991  MAC HIGHER          NEW PRINT
# 599319   CENGAGE L  USED PRINT RENTAL
# 960900   CENGAGE L           BUY USED
# 21751       TAYLOR   NEW PRINT RENTAL
# 261933  HACHETTE B          NEW PRINT
# 707364  HACHETTE B   NEW PRINT RENTAL
# 898272      NORTON            BUY NEW
# 849586  INGRAM PUB         USED PRINT
# 904205      INGRAM            BUY NEW
# 52100        WILEY  USED PRINT RENTAL
# 230845   PENG RAND   NEW PRINT RENTAL
# 285807   PENG RAND   NEW PRINT RENTAL
# 133224       WILEY  USED PRINT RENTAL
# 798876      TAYLOR         USED PRINT
# 918210        SAGE          RENT USED
# 979799         OXF           RENT NEW
# 369128     HACKETT   NEW PRINT RENTAL
# 258171   BROADVIEW   NEW PRINT RENTAL
# 511018   EDILINGUA          NEW PRINT
# 165104      INGRAM         USED PRINT
# 48450      HACKETT   DIGITAL PURCHASE
# 238299    SPRINGER   NEW PRINT RENTAL
# 248647    XANEDU C          NEW PRINT
# 634044         S+S          NEW PRINT
# 987981         OXF           RENT NEW
# 909528  JONES+BART           BUY USED
# 188925      ALFRED   NEW PRINT RENTAL
# 813297  KINOKUNIYA   NEW PRINT RENTAL
# 847790  CENGAGE CO   DIGITAL PURCHASE
# 734740       WILEY  USED PRINT RENTAL
# 769201       WILEY          NEW PRINT
# 70025      PEARSON         USED PRINT
# 15630   AM PSYCHOL  USED PRINT RENTAL
#
#                                                  book_url           isbn  \
# 130550  https://unlv.bncollege.com/c/Simple-Statistics...  9780195330717
# 808783  https://unt.bncollege.com/c/When-the-Little-Th...  9781569242902
# 414148  https://psu.bncollege.com/c/Information-Techno...  9781337101356
# 511743  https://psu.bncollege.com/c/I-Shall-Not-Be-Mov...  9780553354584
# 467431  https://psu.bncollege.com/c/MATLAB-Programming...  9780357030394
# 324869  https://liberty.bncollege.com/c/No-Drama-Disci...  9780345548061
# 648539  https://wayne.bncollege.com/c/Study-Manual-Pro...  9781647563929
# 910845  https://fiu.bncollege.com/shop/fiu/textbook/cr...  9780134477596
# 476270  https://msstate.bncollege.com/c/Voices-in-the-...  9781681371054
# 145354  https://sjsu.bncollege.com/c/Drink-Cultura--Ch...  9781877741074
# 629223  https://wayne.bncollege.com/c/Modern-Business-...  9780357531075
# 177710  https://sjsu.bncollege.com/c/Marugoto-Intermed...  9784384057591
# 226899  https://oakland.bncollege.com/c/Everythings-an...  9781319056278
# 416843  https://tamu.bncollege.com/Textbooks/Aint-I-A-...  9781138821514
# 950640  https://fiu.bncollege.com/shop/fiu/textbook/tr...  9781108436694
# 228429  https://iub.bncollege.com/c/Invitation-to-Asia...  9780190211264
# 117978  https://clemson.bncollege.com/c/Nutrition-From...   978013466826
# 324991  https://liberty.bncollege.com/c/Survey-of-Hist...  9781628922349
# 599319  https://sc.bncollege.com/Textbooks/Fundamental...  9781305094765
# 960900  https://fiu.bncollege.com/shop/BNCB_TextbookDe...   978130595368
# 21751   https://bsu.bncollege.com/Textbooks/Ethics-for...  9781138949201
# 261933  https://iub.bncollege.com/Textbooks/Black-Pant...  9780785197997
# 707364  https://gmu.bncollege.com//c/Presidents-Book-o...  9781610397698
# 898272  https://fiu.bncollege.com/shop/BNCB_TextbookDe...  9780393316995
# 849586  https://charlotte.bncollege.com/c/Sweat/p/MBS_...  9781559365321
# 904205  https://unc.bncollege.com/shop/BNCB_TextbookDe...  
# %%
df2 = df2.reset_index(drop=True)

# %%
textbooks_df = df2.copy()

# %%
textbooks_df.head(5)
# Out:
#   department_id course_id section_id  \
# 0       334_1_9       200          1
# 1       334_1_9       201         01
# 2       334_1_9       201         02
# 3       334_1_9       201         03
# 4       334_1_9       201         04
#
#                                                title  edition   publisher  \
# 0            CENGAGE UNLIMITED - ACCESS (1 SEMESTER)       18   CENGAGE U
# 1  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  MCG CUSTOM
# 2  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  MCG CUSTOM
# 3  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  MCG CUSTOM
# 4  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  MCG CUSTOM
#
#           book_type                                           book_url  \
# 0  DIGITAL PURCHASE  https://bsu.bncollege.com/c/Cengage-Unlimited-...
# 1         NEW PRINT  https://bsu.bncollege.com/c/Financial-Accounti...
# 2         NEW PRINT  https://bsu.bncollege.com/c/Financial-Accounti...
# 3         NEW PRINT  https://bsu.bncollege.com/c/Financial-Accounti...
# 4         NEW PRINT  https://bsu.bncollege.com/c/Financial-Accounti...
#
#             isbn   price
# 0  9780357700006  119.99
# 1  9781264273881  107.90
# 2  9781264273881  107.90
# 3  9781264273881  107.90
# 4  9781264273881  107.90

# %%
textbooks_df.sample(50)
# Out:
#        department_id  course_id section_id  \
# 44478      480_1_172        120         C3
# 335246     572_1_276        199        294
# 8931       334_1_518        160          6
# 317504     572_1_183        404        501
# 349267     572_1_367        200        596
# 410395      619_1_90      11120          2
# 44770      480_1_172        151         B1
# 236480     396_1_170       1202        003
# 306778     572_1_171        203        516
# 50274      480_1_262        743         A1
# 474067     620_1_635        490        901
# 98775      246_1_170        108        003
# 342040   370_370_330        670       0101
# 355557     240_1_260        220        J02
# 239797     693_1_190       0952        010
# 522657     707_1_521      U6387        001
# 537243     327_1_588       4153       0077
# 478893      53_53_28        542         40
# 597084     107330947  107334718  107322029
# 270706   450_450_350         30        101
# 588260     107004991  107011143  106999153
# 153394     684_1_330        314         01
# 255564    8153_2_590      26311        601
# 586277     105161216  105170800  105151846
# 11225      334_1_727        103        800
# 592820     107331233  107334994  107323570
# 94638      656_1_357       6204      37920
# 318175    370_370_84        404       0101
# 389091   370_370_260        661       0101
# 291955   439_439_203        460       001G
# 467844     620_1_405        463        901
# 323946     204_1_420       3113        502
# 346690     572_1_348        303        902
# 617444     105160749  105169664  105154129
# 138682     244_1_150       1000      15171
# 550016   367_367_620        099        010
# 184822    8387_1_325        625        S30
# 427468     740_1_891       1010      26435
# 477280      707_1_47      W1010        001
# 132689      336_1_30       2203      20149
# 236348     693_1_190       0851        073
# 177262     289_1_135        421        010
# 137313      336_1_75       2713      21502
# 357355     572_1_387        226        502
# 142108   632_632_379         63      14373
# 550633   367_367_620        266        002
# 489136     327_1_238       6254       0R01
# 232011     693_1_150       0876        001
# 535356     327_1_577       3165       0M02
# 198456     631_1_330        221      21432
#
#                                                     title  edition  \
# 44478                                   RULES FOR WRITERS  10TH 22
# 335246            SKYEPACK KINE COMPLETE SPORT ACCESS >I<  NON-EXP
# 8931                        ICLICKER2 STUDENT REMOTE REV.       17
# 317504  ENVIRONMENTAL ENGINEERING: PRINCIPLES AND PRAC...       14
# 349267                 PACKBACK QUESTIONS ACCESS CODE >I<      W22
# 410395                                    ASTRONOMY (OER)       18
# 44770                                             PASSING       03
# 236480         CAMPBELL BIOLOGY - WITH MOD. MASTERBIOLOGY  11TH 17
# 306778                                               JANE       15
# 50274   INTRODUCTION TO STATISTICAL LEARNING: WITH APP...       13
# 474067  ON TYRANNY: TWENTY LESSONS FROM THE TWENTIETH ...       17
# 98775                                             PHYSICS   9TH 12
# 342040  DESCRIPTIVE PHYSICAL OCEANOGRAPHY: AN INTRODUC...   6TH 11
# 355557                                      METAMORPHOSES  (REV)04
# 239797                                COMMUNIST MANIFESTO       48
# 522657  ORIGINS OF TERRORISM : PSYCHOLOGIES, IDEOLOGIE...  (REV)98
# 537243  STRATEGIC PLANNING FOR PUBLIC AND NONPROFIT OR...   5TH 18
# 478893  LANGUAGE DISORDERS FROM INFANCY THROUGH ADOLES...   5TH 18
# 597084                      FUND.OF APPL.ELECTROMAGNETICS   7TH 15
# 270706                                       SECOND SHIFT       12
# 588260                           LEADING FROM THE LIBRARY       19
# 153394                                RUSSIAN FAIRY TALES       45
# 255564  24 ITALIAN SONGS & ARIAS COMPLETE: MEDIUM HIGH...       14
# 586277              HISTORICAL KNOWLEDGE,HISTORICAL ERROR       07
# 11225            CULTURAL DIVERSITY IN HEALTH AND ILLNESS   9TH 17
# 592820               TERRORISM+HOMELAND...(LL)-W/MI NDTAP   9TH 17
# 94638                  INTERNATIONAL FINANCIAL MANAGEMENT  13TH 18
# 318175                             MOLECULAR CELL BIOLOGY   9TH 21
# 389091         PHASE TRANSFORMATIONS IN METALS AND ALLOYS   3RD 09
# 291955                             GAME NARRATIVE TOOLBOX       15
# 467844  REENGINEERING THE CORPORATION - REVISED AND UP...   REV 03
# 323946                      LETTER LESSON AND FIRST WORDS       19
# 346690                RADIATION DETECTION AND MEASUREMENT   4TH 10
# 617444              ANAT.+PHYS.F/SPEECH,LANG...-W/ ACCESS   6TH 21
# 138682                     THINKING THROUGH COMMUNICATION   8TH 18
# 550016       LEGAL DRAFTING BY DESIGN: A UNIFIED APPROACH       18
# 184822                          SCIENCE OF SCIENCE POLICY       11
# 427468               SPIRIT CATCHES YOU AND YOU FALL DOWN       12
# 477280                                  FEDERALIST PAPERS       03
# 132689                         BECKER'S WORLD OF THE CELL   9TH 16
# 236348                                      IDEAL HUSBAND       00
# 177262       COMPILERS: PRINCIPLES, TECHNIQUES, AND TOOLS   2ND 07
# 137313  FURNITURE DESIGN AND CONSTRUCTION FOR THE INTE...       09
# 357355                     *PHYSICS WEBASSIGN ACCESS CARD       13
# 142108  ACADEMIC ENCOUNTERS: NATURAL WORLD, LEVEL 1 - ...   2ND 13
# 550633    CASES AND MATERIALS ON STATUTORY INTERPRETATION       12
# 489136      RELIABILITY EVALUATION OF ENGINEERING SYSTEMS   2ND 92
# 232011  O GOD OF PLAYERS : THE STORY OF THE IMMACULATA...       03
# 535356  PUBLICATION MANUAL OF THE AMERICAN PSYCHOLOGIC...   7TH 20
# 198456  NONPROFIT ORGANIZATIONS AND CIVIL SOCIETY IN T...       15
#
#          publisher          book_type  \
# 44478   MAC HIGHER   NEW PRINT RENTAL
# 335246    SKYEPACK          NEW PRINT
# 8931    MAC HIGHER  USED PRINT RENTAL
# 317504  WILEY P CC   DIGITAL PURCHASE
# 349267    PACKBACK          NEW PRINT
# 410395    XANEDU C         USED PRINT
# 44770    PENG RAND         USED PRINT
# 236480     PEARSON          NEW PRINT
# 306778   PENG RAND  USED PRINT RENTAL
# 50274     SPRINGER          NEW PRINT
# 474067   PENG RAND   NEW PRINT RENTAL
# 98775        WILEY         USED PRINT
# 342040    ELSEVIER          NEW PRINT
# 355557   PENG RAND          NEW PRINT
# 239797    INTL PUB         USED PRINT
# 522657   HOPKINS F          NEW PRINT
# 537243       WILEY          NEW PRINT
# 478893    ELSEVIER     DIGITAL RENTAL
# 597084     PEARSON           RENT NEW
# 270706   PENG RAND  USED PRINT RENTAL
# 588260  INGRAM PUB          RENT USED
# 153394   PENG RAND   NEW PRINT RENTAL
# 255564   LEONARD H         USED PRINT
# 586277         UCP            BUY NEW
# 11225      PEARSON     DIGITAL RENTAL
# 592820   CENGAGE L           BUY USED
# 94638    CENGAGE L         USED PRINT
# 318175  MAC HIGHER         USED PRINT
# 389091      TAYLOR  USED PRINT RENTAL
# 291955      TAYLOR         USED PRINT
# 467844    HARP PUB         USED PRINT
# 323946   HEINEMANN         USED PRINT
# 346690       WILEY  USED PRINT RENTAL
# 617444  PLURAL PUB           RENT NEW
# 138682      TAYLOR  USED PRINT RENTAL
# 550016       ASPEN  USED PRINT RENTAL
# 184822  INGRAM PUB   NEW PRINT RENTAL
# 427468  MAC HIGHER   DIGITAL PURCHASE
# 477280   PENG RAND         USED PRINT
# 132689     PEARSON   DIGITAL PURCHASE
# 236348       DOVER          NEW PRINT
# 177262     PEARSON         USED PRINT
# 137313  MAC HIGHER          NEW PRINT
# 357355   WEBASSIGN          NEW PRINT
# 142108        CAMB          NEW PRINT
# 550633   WEST ACAD         USED PRINT
# 489136    SPRINGER         USED PRINT
# 232011  INGRAM PUB   NEW PRINT RENTAL
# 535356  AM PSYCHOL  USED PRINT RENTAL
# 198456      TAYLOR  USED PRINT RENTAL
#
#                                                  book_url           isbn  \
# 44478   https://bu.bncollege.com/c/Rules-for-Writers/p...  9781319244255
# 335246  https://tamu.bncollege.com/c/SKYEPACK-KINE-COM...  2819480261133
# 8931    https://bsu.bncollege.com/c/iClicker2-Student-...  9781498603041
# 317504  https://tamu.bncollege.com/c/Environmental-Eng...  9781118785997
# 349267  https://tamu.bncollege.com/c/PACKBACK-QUESTION...  2819480261218
# 410395  https://rowanbookstore.bncollege.com/c/Astrono...  9781938168284
# 44770   https://bu.bncollege.com/c/Passing/p/MBS_61938...  9780142437278
# 236480  https://lsu.bncollege.com/c/Campbell-Biology--...  9780134683461
# 306778  https://tamu.bncollege.com/c/Jane/p/MBS_193127...  9780143107941
#
#          price
# 44478    48.25
# 335246   46.67
# 8931     38.75
# 317504   86.00
# 349267   38.67
# 410395   43.50
# 44770    10.50
# 236480  325.85
# 306778    7.50
# 50274    79.99
# 474067    6.80
# 98775   221.52
# 342040   99.95
# 355557   12.00
# 239797    2.50
# 522657   20.95
# 537243   62.00
# 478893   40.60
# 597084  205.90
# 270706    8.90
# 588260    6.00
# 153394   13.60
# 255564   11.99
# 586277   34.00
# 11225    44.99
# 592820   91.07
# 94638   195.00
# 318175  114.00
# 389091   49.40
# 291955   42.71
# 467844   12.74
# 323946   25.79
# 346690  134.25
# 617444  169.85
# 138682   70.55
# 550016   59.55
# 184822   70.80
# 427468   10.99
# 477280    5.96
# 132689   74.99
# 236348    3.12
# 177262  161.19
# 137313  100.00
# 357355   48.67
# 142108   59.85
# 550633  164.25
# 489136  149.99
# 232011   30.10
# 535356   27.15
# 198456   37.50

# %% [markdown]
# # Merge courses and textbooks dataframes with inner join

# %% [markdown]
# ### *merge_courses_and_textbooks_df*

# %%
# Inner merge on both dataframes on common id fields

merge_df = pd.merge(courses_df, textbooks_df, on=["department_id", "course_id", "section_id"], how="inner")

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610343 entries, 0 to 610342
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   department_id  610343 non-null  object
#  1   course_id      610343 non-null  object
#  2   section_id     610343 non-null  object
#  3   university     610343 non-null  object
#  4   term           610343 non-null  object
#  5   department     610343 non-null  object
#  6   course         610343 non-null  object
#  7   section        610343 non-null  object
#  8   title          610343 non-null  object
#  9   edition        610343 non-null  object
#  10  publisher      610343 non-null  object
#  11  book_type      610343 non-null  object
#  12  book_url       610343 non-null  object
#  13  isbn           610343 non-null  object
#  14  price          610343 non-null  float64
# dtypes: float64(1), object(14)
# memory usage: 74.5+ MB

# %%
merge_df.drop_duplicates()
# Out:
#        department_id  course_id section_id                        university  \
# 0            334_1_9        200          1             BALL STATE UNIVERSITY
# 1            334_1_9        201         01             BALL STATE UNIVERSITY
# 2            334_1_9        201         02             BALL STATE UNIVERSITY
# 3            334_1_9        201         03             BALL STATE UNIVERSITY
# 4            334_1_9        201         04             BALL STATE UNIVERSITY
# ...              ...        ...        ...                               ...
# 610338     107904486  107916708  107902516  FLORIDA INTERNATIONAL UNIVERSITY
# 610339     107904486  107916805  107902503  FLORIDA INTERNATIONAL UNIVERSITY
# 610340     107904486  107916805  107902503  FLORIDA INTERNATIONAL UNIVERSITY
# 610341     107904486  107916805  107902504  FLORIDA INTERNATIONAL UNIVERSITY
# 610342     107904486  107916805  107902504  FLORIDA INTERNATIONAL UNIVERSITY
#
#           term department course section  \
# 0       SPRING        ACC    200       1
# 1       SPRING        ACC    201      01
# 2       SPRING        ACC    201      02
# 3       SPRING        ACC    201      03
# 4       SPRING        ACC    201      04
# ...        ...        ...    ...     ...
# 610338    FALL        PHC   6530     U01
# 610339    FALL        PHC   6374     RXC
# 610340    FALL        PHC   6374     RXC
# 610341    FALL        PHC   6374    RX02
# 610342    FALL        PHC   6374    RX02
#
#                                                     title  edition  \
# 0                 CENGAGE UNLIMITED - ACCESS (1 SEMESTER)       18
# 1       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# 2       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# 3       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# 4       FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21
# ...                                                   ...      ...
# 610338                      KOTCH'S MATERNAL+CHILD HEALTH   4TH 22
# 610339                     HAZARD MITIGATION+PREPAREDNESS   2ND 17
# 610340                     HAZARD MITIGATION+PREPAREDNESS   2ND 17
# 610341                     HAZARD MITIGATION+PREPAREDNESS   2ND 17
# 610342                     HAZARD MITIGATION+PREPAREDNESS   2ND 17
#
#          publisher         book_type  \
# 0        CENGAGE U  DIGITAL PURCHASE
# 1       MCG CUSTOM         NEW PRINT
# 2       MCG CUSTOM         NEW PRINT
# 3       MCG CUSTOM         NEW PRINT
# 4       MCG CUSTOM         NEW PRINT
# ...            ...               ...
# 610338  JONES+BART       BUY DIGITAL
# 610339      TAYLOR          BUY USED
# 610340      TAYLOR           BUY NEW
# 610341      TAYLOR          BUY USED
# 610342      TAYLOR           BUY NEW
#
#                                                  book_url           isbn  \
# 0       https://bsu.bncollege.com/c/Cengage-Unlimited-...  9780357700006
# 1       https://bsu.bncollege.com/c/Financial-Accounti...  9781264273881
# 2       https://bsu.bncollege.com/c/Financial-Accounti...  9781264273881
# 3       https://bsu.bncollege.com/c/Financial-Accounti...  9781264273881
# 4       https://bsu.bncollege.com/c/Financial-Accounti...  9781264273881
# ...                                                   ...            ...
# 610338  https://fiu.bncollege.com/shop/BNCB_TextbookDe...  9781284200256
# 610339  https://fiu.bncollege.com/shop/fiu/textbook/ha...  9781466595569
# 610340  https://fiu.bncollege.com/shop/fiu/textbook/ha...  9781466595569
# 610341  https://fiu.bncollege.com/shop/fiu/textbook/ha...  9781466595569
# 610342  https://fiu.bncollege.com/shop/fiu/textbook/ha...  9781466595569
#
#          price
# 0       119.99
# 1       107.90
# 2       107.90
# 3       107.90
# 4       107.90
# ...        ...
# 610338   59.12
# 610339   90.00
# 610340  120.00
# 610341   90.00
# 610342  120.00
#
# [607184 rows x 15 columns]

# %%
merge_df = merge_df[["university", "term", "department", "course", "section", "title", "edition", "price",\
                     "isbn", "publisher", "book_type", "book_url"]]

# %%
merge_df.sample(50)
# Out:
#                                        university    term department course  \
# 186048          KENT STATE UNIVERSITY KENT CAMPUS    FALL       ECED  44444
# 397740                             UNLV BOOKSTORE  SPRING       NURS   740R
# 425235                  UNIVERSITY OF MISSISSIPPI  SPRING       MGMT    495
# 483633                    GEORGE MASON UNIVERSITY  SPRING        AVT    413
# 561672  UNIVERSITY OF NORTH CAROLINA AT CHARLOTTE    FALL       LBST   2101
# 87428              INDIANA UNIVERSITY BLOOMINGTON    FALL      ENG-W    131
# 420955                  UNIVERSITY OF MISSISSIPPI  SPRING        ENG    222
# 410255                                      UPENN  SPRING       NURS    547
# 212973                 PENN STATE UNIVERSITY PARK  SPRING        FIN    301
# 1756                        BALL STATE UNIVERSITY  SPRING       CHEM    230
# 56802                           BOSTON UNIVERSITY  SPRING     MET AD    746
# 247705                 PENN STATE UNIVERSITY PARK  SPRING         CC   490W
# 514818                  UNIVERSITY OF NORTH TEXAS  SUMMER       FINA   3770
# 65898          121  THINKING LIKE AN ENGINEER - MYLAB AND PRT. OPTION
# 328686         010           BORN TO USE MICS: READING NAS'S ILLMATIC
# 336631         010  WRITING STYLE AND STANDARDS IN UNDERGRADUATE E...
#
#         edition   price           isbn   publisher          book_type  \
# 186048       07   22.87  9781560902119        AMLE         USED PRINT
# 397740   5TH 20   65.24  9780323554947    ELSEVIER         USED PRINT
# 425235       12    8.00  9780062183613    HARP PUB  USED PRINT RENTAL
# 483633   2ND 08   24.70  9781581155099         S+S   NEW PRINT RENTAL
# 561672       02    7.05  9781588380913   NEW SOUTH  USED PRINT RENTAL
# 87428        12    6.60  9781423218654   BARCHARTS          NEW PRINT
# 420955   2ND 09   24.90  9781551119779   BROADVIEW  USED PRINT RENTAL
# 410255   7TH 21   11.99  9780323759243    ELSEVIER         USED PRINT
# 212973  10TH 20  170.56    97812607039         MCG          NEW PRINT
# 1756     3RD 16  259.99  9780321937711     PEARSON          NEW PRINT
# 56802   10TH 18  124.75  9781305972599   CENGAGE L  USED PRINT RENTAL
# 247705       19   49.40  9781506349152        SAGE  USED PRINT RENTAL
# 514818  10TH 20   89.99  9780134897288  RENT PEARS   DIGITAL PURCHASE
# 556666       14    6.75   978014310733   PENG RAND         USED PRINT
# 427777   4TH 19   61.75  9781506333403        SAGE  USED PRINT RENTAL
# 575904   5TH 16   83.33  9781119661528       WILEY          NEW PRINT
# 94672        15   12.92  9781632861023  MAC HIGHER         USED PRINT
# 226471   4TH 19   43.49  9781337406451   CENGAGE L     DIGITAL RENTAL
# 154306   2ND 17   36.55  9781319030421  MAC HIGHER  USED PRINT RENTAL
# 229663   2ND 20   36.38  9781975076498    XANEDU C         USED PRINT
# 433439       11    6.95  9781423217367   BARCHARTS          NEW PRINT
# 141672       21   40.00  8220125277077   TOPHAT CC   DIGITAL PURCHASE
# 142809       11    6.95  9781423217428   BARCHARTS          NEW PRINT
# 425644    23 RD  182.15   978012820007    ACAD ENE         USED PRINT
# 153665       20   31.20  9781644851821  FOUNTAINHE          NEW PRINT
# 445429       17   18.00  9781632863164  MAC HIGHER         USED PRINT
# 189489  19TH 22  158.15  9781264125814         MCG   NEW PRINT RENTAL
# 280990     13TH   41.56  9780136893929     PEARSON         USED PRINT
# 57887      2020  139.13  9780136797265   PEARSON C          NEW PRINT
# 592006   7TH 20   35.99  9781433832161  AM PSYCHOL   DIGITAL PURCHASE
# 475683       16   20.10  9780393923209      NORTON          NEW PRINT
# 429828       17   18.57  9781319140175  MAC HIGHER          NEW PRINT
# 223278   2ND 09   58.00  9780618976133   CENGAGE L   NEW PRINT RENTAL
# 503840       15   99.95  9780415645355      TAYLOR          NEW PRINT
# 122076   2ND 18    5.62  9781583315149        ACSI         USED PRINT
# 525645   4TH 20   90.91  9781319195861  MAC HIGHER          NEW PRINT
# 571828   5TH 11   88.90  9780137072453     PEARSON  USED PRINT RENTAL
# 470515   LATEST  166.90  9780754665519      TAYLOR   NEW PRINT RENTAL
# 545551  10TH 20   53.35  9780367225889      TAYLOR  USED PRINT RENTAL
# 571828  https://ucf-vc.bncollege.com/c/Public-Relation...
# 470515  https://columbia.bncollege.com/c/-Shakespeare-...
# 545551  https://wsubookie.bncollege.com/c/Social-Inequ...
# 161727  https://northeastern.bncollege.com/c/Organizat...
# 505552  https://unt.bncollege.com/c/Compact-Bedford-In...
# 437949  https://sc.bncollege.com/c/Thomas-Calculus-Ear...
# 227670  https://psu.bncollege.com/c/Introduction-to-He...
# 490426  https://gmu.bncollege.com//c/Jonas-and-Kovners...
# 258323  https://rowanbookstore.bncollege.com/c/Classic...
# 584301  https://ucf.bncollege.com/c/Managerial-Epidemi...
# 502028  https://unt.bncollege.com/c/Professional-Couns...
# 65898   https://clemson.bncollege.com/c/Thinking-Like-...
# 328686  https://udel.bncollege.com/c/Born-to-Use-Mics-...
# 336631  https://udel.bncollege.com/c/Writing-Style-and...

# %%
merge_df = merge_df.reset_index(drop=True)

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610343 entries, 0 to 610342
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   university  610343 non-null  object
#  1   term        610343 non-null  object
#  2   department  610343 non-null  object
#  3   course      610343 non-null  object
#  4   section     610343 non-null  object
#  5   title       610343 non-null  object
#  6   edition     610343 non-null  object
#  7   price       610343 non-null  float64
#  8   isbn        610343 non-null  object
#  9   publisher   610343 non-null  object
#  10  book_type   610343 non-null  object
#  11  book_url    610343 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 55.9+ MB

# %% [markdown]
# #### Connect to engine

# %% [markdown]
# # Import Security
# from config.py import user

# %%
protocol = "postgresql"
user = "postgres"
password = "bootcamp"
host = "localhost"
port = "5432"
db = "library_db"
conn_string = f'{protocol}://{user}:{password}@{host}:{port}/{db}'
engine = create_engine(conn_string)

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['course_textbooks']

# %%
merge_df.to_sql(name='course_textbooks', con=engine, if_exists='append', index=False)
# Out:
# 343

# %%
pd.read_sql_query('select * from course_textbooks', con=engine).head(5)
# Out:
#    id             university    term department course section  \
# 0   1  BALL STATE UNIVERSITY  SPRING        ACC    200       1
# 1   2  BALL STATE UNIVERSITY  SPRING        ACC    201      01
# 2   3  BALL STATE UNIVERSITY  SPRING        ACC    201      02
# 3   4  BALL STATE UNIVERSITY  SPRING        ACC    201      03
# 4   5  BALL STATE UNIVERSITY  SPRING        ACC    201      04
#
#                                                title  edition   price  \
# 0            CENGAGE UNLIMITED - ACCESS (1 SEMESTER)       18  119.99
# 1  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  107.90
# 2  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  107.90
# 3  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  107.90
# 4  FINANCIAL ACCOUNTING: INFORMATION FOR DECISION...  10TH 21  107.90
#
#             isbn   publisher         book_type  \
# 0  9780357700006   CENGAGE U  DIGITAL PURCHASE
# 1  9781264273881  MCG CUSTOM         NEW PRINT
# 2  9781264273881  MCG CUSTOM         NEW PRINT
# 3  9781264273881  MCG CUSTOM         NEW PRINT
# 4  9781264273881  MCG CUSTOM         NEW PRINT
#
#                                             book_url
# 0  https://bsu.bncollege.com/c/Cengage-Unlimited-...
# 1  https://bsu.bncollege.com/c/Financial-Accounti...
# 2  https://bsu.bncollege.com/c/Financial-Accounti...
# 3  https://bsu.bncollege.com/c/Financial-Accounti...
# 4  https://bsu.bncollege.com/c/Financial-Accounti...
